# %%
people = { "first" : ['nisheet','rohan','amit','abhi','priyanshu','shlok'],
            "last" : ['patel', 'soni', 'soni', 'patel','patel','bhavsar'],
          "email" : ["nisheet@gmail.com", "rohansoni@gmail.com","amitsoni@gmail.com","abhi@gmail.com",'priyanshu@gmail.com','sb22@gmail.com']
         }

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#        first     last                email
# 0    nisheet    patel    nisheet@gmail.com
# 1      rohan     soni  rohansoni@gmail.com
# 2       amit     soni   amitsoni@gmail.com
# 3       abhi    patel       abhi@gmail.com
# 4  priyanshu    patel  priyanshu@gmail.com
# 5      shlok  bhavsar       sb22@gmail.com

# %%
df['first'] + ' ' + df['last']
# Out:
# 0      nisheet patel
# 1         rohan soni
# 2          amit soni
# 3         abhi patel
# 4    priyanshu patel
# 5      shlok bhavsar
# dtype: object

# %% [markdown]
# ## Adding Two Columns

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#        first     last                email        full_name
# 0    nisheet    patel    nisheet@gmail.com    nisheet patel
# 1      rohan     soni  rohansoni@gmail.com       rohan soni
# 2       amit     soni   amitsoni@gmail.com        amit soni
# 3       abhi    patel       abhi@gmail.com       abhi patel
# 4  priyanshu    patel  priyanshu@gmail.com  priyanshu patel
# 5      shlok  bhavsar       sb22@gmail.com    shlok bhavsar

# %% [markdown]
# ## Remove Columns

# %%
df.drop(columns=['first','last'], inplace=True)

# %%
df
# Out:
#                  email        full_name
# 0    nisheet@gmail.com    nisheet patel
# 1  rohansoni@gmail.com       rohan soni
# 2   amitsoni@gmail.com        amit soni
# 3       abhi@gmail.com       abhi patel
# 4  priyanshu@gmail.com  priyanshu patel
# 5       sb22@gmail.com    shlok bhavsar

# %%
# To undo the changes
df['full_name'].str.split(' ',expand=True)
# Out:
#            0        1
# 0    nisheet    patel
# 1      rohan     soni
# 2       amit     soni
# 3       abhi    patel
# 4  priyanshu    patel
# 5      shlok  bhavsar

# %%
# adding frist and last from full_name
df[['first','last']] = df['full_name'].str.split(' ',expand=True)

# %%
df
# Out:
#                  email        full_name      first     last
# 0    nisheet@gmail.com    nisheet patel    nisheet    patel
# 1  rohansoni@gmail.com       rohan soni      rohan     soni
# 2   amitsoni@gmail.com        amit soni       amit     soni
# 3       abhi@gmail.com       abhi patel       abhi    patel
# 4  priyanshu@gmail.com  priyanshu patel  priyanshu    patel
# 5       sb22@gmail.com    shlok bhavsar      shlok  bhavsar

# %%
df.append({'first': 'Tony'}, ignore_index=True)
# Out:
#                  email        full_name      first     last
# 0    nisheet@gmail.com    nisheet patel    nisheet    patel
# 1  rohansoni@gmail.com       rohan soni      rohan     soni
# 2   amitsoni@gmail.com        amit soni       amit     soni
# 3       abhi@gmail.com       abhi patel       abhi    patel
# 4  priyanshu@gmail.com  priyanshu patel  priyanshu    patel
# 5       sb22@gmail.com    shlok bhavsar      shlok  bhavsar
# 6                  NaN              NaN       Tony      NaN

# %%
people = { "first" : ['Tony', "Steve"],
            "last" : ["Stark", "Rogers"],
          "email" : ["ironman@avenger.com","cp@avenger.com"]
         }
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last                email
# 0   Tony   Stark  ironman@avenger.com
# 1  Steve  Rogers       cp@avenger.com

# %% [markdown]
# ## Adding Rows

# %%
df = df.append(df2, ignore_index=True)

# %%
df
# Out:
#                  email        full_name      first     last
# 0    nisheet@gmail.com    nisheet patel    nisheet    patel
# 1  rohansoni@gmail.com       rohan soni      rohan     soni
# 2   amitsoni@gmail.com        amit soni       amit     soni
# 3       abhi@gmail.com       abhi patel       abhi    patel
# 4  priyanshu@gmail.com  priyanshu patel  priyanshu    patel
# 5       sb22@gmail.com    shlok bhavsar      shlok  bhavsar
# 6  ironman@avenger.com              NaN       Tony    Stark
# 7       cp@avenger.com              NaN      Steve   Rogers

# %% [markdown]
# ## Remove Rows

# %%
df.drop(index=7)
# Out:
#                  email        full_name      first     last
# 0    nisheet@gmail.com    nisheet patel    nisheet    patel
# 1  rohansoni@gmail.com       rohan soni      rohan     soni
# 2   amitsoni@gmail.com        amit soni       amit     soni
# 3       abhi@gmail.com       abhi patel       abhi    patel
# 4  priyanshu@gmail.com  priyanshu patel  priyanshu    patel
# 5       sb22@gmail.com    shlok bhavsar      shlok  bhavsar
# 6  ironman@avenger.com              NaN       Tony    Stark

# %%
# if i want to remove rows who have last == soni
df.drop(index=df[df['last'] == 'soni'].index)
# Out:
#                  email        full_name      first     last
# 0    nisheet@gmail.com    nisheet patel    nisheet    patel
# 3       abhi@gmail.com       abhi patel       abhi    patel
# 4  priyanshu@gmail.com  priyanshu patel  priyanshu    patel
# 5       sb22@gmail.com    shlok bhavsar      shlok  bhavsar
# 6  ironman@avenger.com              NaN       Tony    Stark
# 7       cp@avenger.com              NaN      Steve   Rogers
